# %% [markdown]
# # Profile allele count from genotype data via dask.array

# %%
import sys
sys.path.insert(0, '..')
import zarr
print('zarr', zarr.__version__)
from zarr import blosc
import numpy as np
import h5py
import multiprocessing
import dask
import dask.array as da
from dask.diagnostics import Profiler, ResourceProfiler, CacheProfiler
from dask.diagnostics.profile_visualize import visualize
from cachey import nbytes
import bokeh
from bokeh.io import output_notebook
output_notebook()
from functools import reduce
import operator
import allel
# Out:
# zarr 1.0.1.dev18+dirty
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b153ad5f-436a-4afb-945c-87790add89c8">Loading BokehJS ...</span>
#     </div>

# %%
callset = h5py.File('/data/coluzzi/ag1000g/data/phase1/release/AR3/variation/main/hdf5/ag1000g.phase1.ar3.pass.h5',
                    mode='r')
genotype = callset['3R/calldata/genotype']
genotype
# Out:
# <HDF5 dataset "genotype": shape (13167162, 765, 2), type "|i1">

# %%
# copy into a zarr array
# N.B., chunks in HDF5 are too small really, use something bigger
chunks = (genotype.chunks[0], genotype.chunks[1] * 20, genotype.chunks[2])
genotype_zarr = zarr.array(genotype, chunks=chunks, compression='blosc',
                           compression_opts=dict(cname='lz4', clevel=1, shuffle=2))
genotype_zarr
# Out:
# zarr.core.Array((13167162, 765, 2), int8, chunks=(6553, 200, 2), order=C)
#   compression: blosc; compression_opts: {'clevel': 1, 'cname': 'lz4', 'shuffle': 2}
#   nbytes: 18.8G; nbytes_stored: 683.2M; ratio: 28.1; initialized: 8040/8040
#   store: builtins.dict

# %% [markdown]
# We want to perform an allele count. Compare serial and parallel implementations, and compare working direct from HDF5 versus from Zarr.

# %%
# %%time
# linear implementation from HDF5 on disk
allel.GenotypeChunkedArray(genotype).count_alleles()
# Out:
# CPU times: user 1min 50s, sys: 512 ms, total: 1min 51s
# Wall time: 1min 50s
# AlleleCountsChunkedArray((13167162, 4), int32, chunks=(65536, 4))
#   nbytes: 200.9M; cbytes: 38.3M; cratio: 5.2;
#   compression: blosc; compression_opts: cparams(clevel=5, shuffle=1, cname='lz4', quantize=0);
#   data: bcolz.carray_ext.carray

# %%
# %%time
# linear implementation from zarr in memory
# (although blosc can use multiple threads internally)
allel.GenotypeChunkedArray(genotype_zarr).count_alleles()
# Out:
# CPU times: user 2min 27s, sys: 2.14 s, total: 2min 29s
# Wall time: 1min 23s
# AlleleCountsChunkedArray((13167162, 4), int32, chunks=(65536, 4))
#   nbytes: 200.9M; cbytes: 38.3M; cratio: 5.2;
#   compression: blosc; compression_opts: cparams(clevel=5, shuffle=1, cname='lz4', quantize=0);
#   data: bcolz.carray_ext.carray

# %%
# multi-threaded implementation from HDF5 on disk
gd = allel.model.dask.GenotypeDaskArray.from_array(genotype, chunks=chunks)
ac = gd.count_alleles(max_allele=3)
with Profiler() as prof, ResourceProfiler(dt=1) as rprof:
    ac.compute(num_workers=8)
visualize([prof, rprof], min_border_bottom=60, min_border_top=60);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="98edad68-f719-47b3-b786-d42c3f09c96d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
subtype":"Figure","type":"Plot"},"ticker":{"id":"d9c23e7d-b4ba-4bc4-a25d-76ba6ec76f77","type":"BasicTicker"},"y_range_name":"memory"},"id":"f89c2c36-9329-4661-80e5-7a5e4344e1a3","type":"LinearAxis"},{"attributes":{},"id":"f3c154ee-49be-4319-b5d5-45a8941ec4ea","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["function","key","x","color","width","y"],"data":{"color":["#7fcdbb","#2c7fb8","#7fcdbb","#2c7fb8","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#2c7fb8","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#2c7fb8","#7fcdbb","#7fcdbb","#2c7fb8","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb","#2c7fb8","#7fcdbb","#2c7fb8","#7fcdbb","#7fcdbb","#7fcdbb","#7fcdbb", ...

# %%
# multi-threaded implementation from zarr in memory
gdz = allel.model.dask.GenotypeDaskArray.from_array(genotype_zarr, chunks=chunks)
acz = gdz.count_alleles(max_allele=3)
with Profiler() as prof, ResourceProfiler(dt=1) as rprof:
    acz.compute(num_workers=8)
visualize([prof, rprof], min_border_bottom=60, min_border_top=60);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="11d8090f-9e93-4d9e-8c68-c3ce4ffb069e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("11d8090f-9e93-4d9e-8c68-c3ce4ffb069e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '11d8090f-9e93-4d9e-8c68-c3ce4ffb069e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cb7acd27-8c8e-4581-a831-e95b1277b412":{"roots":{"references":[{"attributes":{"children":[{"id":"c8472626-e8c5-4f0c-be01-e6706a74e961","type":"Row"},{"id":"3efa4c7f-d028-4287-b2fc-ddc9d5ff13a6","type":"Row"}]},"id":"8d328733-07cf-4583-9bd1-0e8510579f84","type":"Column"},{"attributes":{"legends":[["% CPU",[{"id":"599c3ece-f0e9-434c-9ddb-663c6e3c02b7","type":"GlyphRenderer"}]],["Memory",[{"id":"79be33a0-1ec1-484f-b675-265391e03b42","type":"GlyphRenderer"}]]],"plot":{"id":"c203f09b-6e5c-4fd4-aeff-c06f5601c757","subtype":"Figure","type":"Plot"}},"id":"f4ecd203-acd8-4fc2-b361-41c5553b427b","type":"Legend"},{"attributes":{"dimensions":["width"],"plot":{"id":"86910f6c-a603-4a3a-a750-8714499200bc","subtype":"Figure","type":"Plot"}},"id":"8561593c-4143-4697-b717-fa7bb380d9e8","type":"WheelZoomTool"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"86910f6c-a603-4a3a-a750-8714499200bc","subtype":"Figure","type":"Plot"},"ticker":{"id":"c67b4794-dd7d-476d-bff2-b02725bb9c41","type":"CategoricalTicker"}},"id":"1df78f21-40d2-4398-9edd-be294fd7077e","type":"Grid"},{"attributes":{"plot":{"id":"86910f6c-a603-4a3a-a750-8714499200bc","subtype":"Figure","type":"Plot"}},"id":"5358f456-4b63-4506-90f5-cbffa79afb63","type":"ResizeTool"},{"attributes":{"plot":{"id":"c203f09b-6e5c-4fd4-aeff-c06f5601c757","subtype":"Figure","type":"Plot"}},"id":"8a79b881-8395-4d26-900e-94a795b63339","type":"