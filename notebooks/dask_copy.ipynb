# %% [markdown]
# # Profile array copy via dask threaded scheduler

# %% [markdown]
# This notebook profiles a very simple array copy operation, using synthetic data.

# %%
import sys
sys.path.insert(0, '..')
import zarr
print('zarr', zarr.__version__)
from zarr import blosc
import numpy as np
import h5py
import bcolz
# don't let bcolz use multiple threads internally, we want to 
# see whether dask can make good use of multiple CPUs
bcolz.set_nthreads(1)
import multiprocessing
import dask
import dask.array as da
from dask.diagnostics import Profiler, ResourceProfiler, CacheProfiler
from dask.diagnostics.profile_visualize import visualize
from cachey import nbytes
import bokeh
from bokeh.io import output_notebook
output_notebook()
# Out:
# zarr 1.0.1.dev18+dirty
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d4821cb3-378c-411d-a941-d0708c0c532b">Loading BokehJS ...</span>
#     </div>

# %%
import tempfile
import operator
from functools import reduce
from zarr.util import human_readable_size


def h5fmem(**kwargs):
    """Convenience function to create an in-memory HDF5 file."""

    # need a file name even tho nothing is ever written
    fn = tempfile.mktemp()

    # file creation args
    kwargs['mode'] = 'w'
    kwargs['driver'] = 'core'
    kwargs['backing_store'] = False

    # open HDF5 file
    h5f = h5py.File(fn, **kwargs)

    return h5f


def h5d_diagnostics(d):
    """Print some diagnostics on an HDF5 dataset."""
    
    print(d)
    nbytes = reduce(operator.mul, d.shape) * d.dtype.itemsize
    cbytes = d._id.get_storage_size()
    if cbytes > 0:
        ratio = nbytes / cbytes
    else:
        ratio = np.inf
    r = '  compression: %s' % d.compression
    r += '; compression_opts: %s' % d.compression_opts
    r += '; shuffle: %s' % d.shuffle
    r += '\n  nbytes: %s' % human_readable_size(nbytes)
    r += '; nbytes_stored: %s' % human_readable_size(cbytes)
    r += '; ratio: %.1f' % ratio
    r += '; chunks: %s' % str(d.chunks)
    print(r)

# %%
def profile_dask_copy(src, dst, chunks, num_workers=multiprocessing.cpu_count(), dt=0.1, lock=True):
    dsrc = da.from_array(src, chunks=chunks)
    with Profiler() as prof, ResourceProfiler(dt=dt) as rprof:
        da.store(dsrc, dst, num_workers=num_workers, lock=lock)
    visualize([prof, rprof], min_border_top=60, min_border_bottom=60)

# %% [markdown]
# ## NumPy arrays

# %%
# a1 = np.arange(400000000, dtype='i4')
a1 = np.random.normal(2000, 1000, size=200000000).astype('u2')
a1
# Out:
# array([1314, 2727, 2905, ..., 1958, 1325, 1971], dtype=uint16)

# %%
human_readable_size(a1.nbytes)
# Out:
# '381.5M'

# %%
a2 = np.empty_like(a1)

# %%
chunks = 2**20,  # 4M

# %%
# %time a2[:] = a1
# Out:
# CPU times: user 56 ms, sys: 36 ms, total: 92 ms
# Wall time: 91.7 ms

# %%
profile_dask_copy(a1, a2, chunks, lock=True, dt=.01)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a97c4377-a1b6-4f42-b977-cae8216bc234"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a97c4377-a1b6-4f42-b977-cae8216bc234");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a97c4377-a1b6-4f42-b977-cae8216bc234' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {
type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"43bc45e4-a88a-4446-8d7f-c40f23e4d7b0","type":"Line"},{"attributes":{"plot":null,"text":"Profile Results"},"id":"31754d3a-a52e-4442-a1f3-6788fc8e5fb4","type":"Title"},{"attributes":{},"id":"ebcb7204-dde8-43a8-9ffa-c7ec5fb8bbd4","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#41b6c4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"1040332c-ba0e-4376-a249-da8b6b8607a7","type":"Line"},{"attributes":{},"id":"72ba6b70-ac23-4986-b9f6-fa4ce6f41853","type":"BasicTicker"},{"attributes":{"legends":[["% CPU",[{"id":"5092df3a-874c-4b28-9fac-83ac0bd018ac","type":"GlyphRenderer"}]],["Memory",[{"id":"e909b29e-2dc1-4b71-a1f9-342116e69a28","type":"GlyphRenderer"}]]],"plot":{"id":"c31cec60-6a97-4674-849b-27ec50ce3671","subtype":"Figure","type":"Plot"}},"id":"b53e324a-5c5d-4221-a358-ad58ee0dec7b","type":"Legend"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"92ee02ab-a904-4be8-8a7c-ec0d7af7cd98","subtype":"Figure","type":"Plot"},"ticker":{"id":"044f0ea4-fe80-4a4b-a9f0-1108a150b420","type":"BasicTicker"}},"id":"8665ba6b-980e-42af-bd62-a03484673bd3","type":"Grid"},{"attributes":{},"id":"b4f3666e-5c5c-4eab-80b5-5f7be270a4c7","type":"ToolEvents"},{"attributes":{"callback":null,"end":739.3},"id":"08c43fd5-36e1-4069-a5a9-adf67b9e866c","type":"Range1d"},{"attributes":{"below":[{"id":"6c62d8fd-402c-4309-90ff-094920 ...

# %% [markdown]
# ## Zarr arrays (in-memory)

# %%
z1 = zarr.array(a1, chunks=chunks, compression='blosc', 
                compression_opts=dict(cname='lz4', clevel=1, shuffle=2))
z1
# Out:
# zarr.core.Array((200000000,), uint16, chunks=(1048576,), order=C)
#   compression: blosc; compression_opts: {'clevel': 1, 'cname': 'lz4', 'shuffle': 2}
#   nbytes: 381.5M; nbytes_stored: 318.2M; ratio: 1.2; initialized: 191/191
#   store: builtins.dict

# %%
z2 = zarr.empty_like(z1)
z2
# Out:
# zarr.core.Array((200000000,), uint16, chunks=(1048576,), order=C)
#   compression: blosc; compression_opts: {'clevel': 1, 'cname': 'lz4', 'shuffle': 2}
#   nbytes: 381.5M; nbytes_stored: 294; ratio: 1360544.2; initialized: 0/191
#   store: builtins.dict

# %%
profile_dask_copy(z1, z2, chunks, lock=True, dt=.02)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d94221f3-a813-4dff-93c0-9cd54781ed8d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d94221f3-a813-4dff-93c0-9cd54781ed8d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd94221f3-a813-4dff-93c0-9cd54781ed8d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2250e860-3c53-44ad-b5be-b588f1723052":{"roots":{"references":[{"attributes":{"data_source":{"id":"1f0ea86e-be8d-4805-9ffb-4de3da3c500d","type":"ColumnDataSource"},"glyph":{"id":"a7d29822-03a7-49ee-b400-f32f12c29c3c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":
ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"65f52d18-25a0-4d87-b7e7-78ce312e01e0","type":"BasicTicker"}},"id":"ba907755-552a-42c6-a19d-71240c50825b","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dd778cd2-494e-4c61-84d4-f6b5770b4aeb","type":"SaveTool"},{"id":"b6c0ccbe-525f-42c3-a4d5-af93062e6e25","type":"ResetTool"},{"id":"be6f539d-a50e-4626-8c69-d7ee063932ee","type":"ResizeTool"},{"id":"754dce13-b2d7-40c9-9869-f097eb7e17f9","type":"WheelZoomTool"},{"id":"f3446d09-d9de-4314-b262-6693728a838d","type":"PanTool"}]},"id":"2fb55c94-4717-46c7-bb28-34b47a5f9087","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b256ead-317f-4b89-88e5-c11ed5a169e9","type":"Line"},{"attributes":{"plot":{"id":"eed784eb-5cb8-40d4-b5e2-7fe310aa83ce","subtype":"Figure","type":"Plot"}},"id":"973e89a7-aea8-4cda-9e18-9b391d2731bf","type":"ResetTool"},{"attributes":{},"id":"71974108-8c06-471f-b693-dc3df0d2eeab","type":"BasicTickFormatter"},{"attributes":{"dimensions":["width"],"plot":{"id":"e04928bc-b5f3-4008-a123-28818631cba0","subtype":"Figure","type":"Plot"}},"id":"754dce13-b2d7-40c9-9869-f097eb7e17f9","type":"WheelZoomTool"},{"attributes":{},"id":"10e44447-6b7c-4e52-b3b5-f8ddeef782c9","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"eed784eb-5cb8-40d4-b5e2-7fe310aa83ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"355d081a-1ab2-417e-96b7-341253fe2259","type":"Categori ...

# %%
# for comparison, using blosc internal threads
# %timeit -n3 -r5 z2[:] = z1
# Out:
# 3 loops, best of 5: 251 ms per loop

# %%
# %prun z2[:] = z1

# %% [markdown]
# Without the dask lock, we get better CPU utilisation.

# %% [markdown]
# ## HDF5 datasets (in-memory)

# %%
h5f = h5fmem()
h5f
# Out:
# <HDF5 file "tmp0kuotgrr" (mode r+)>

# %%
h1 = h5f.create_dataset('h1', data=a1, chunks=chunks, compression='lzf', shuffle=True)
h5d_diagnostics(h1)
# Out:
# <HDF5 dataset "h1": shape (200000000,), type "<u2">
#   compression: lzf; compression_opts: None; shuffle: True
#   nbytes: 381.5M; nbytes_stored: 357.4M; ratio: 1.1; chunks: (1048576,)

# %%
h2 = h5f.create_dataset('h2', shape=h1.shape, chunks=h1.chunks, 
                        compression=h1.compression, compression_opts=h1.compression_opts, 
                        shuffle=h1.shuffle)
h5d_diagnostics(h2)
# Out:
# <HDF5 dataset "h2": shape (200000000,), type "<f4">
#   compression: lzf; compression_opts: None; shuffle: True
#   nbytes: 762.9M; nbytes_stored: 0; ratio: inf; chunks: (1048576,)

# %%
profile_dask_copy(h1, h2, chunks, lock=True, dt=0.1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bc0adf27-f6b4-49fe-ad2e-a7169a21d18b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc0adf27-f6b4-49fe-ad2e-a7169a21d18b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc0adf27-f6b4-49fe-ad2e-a7169a21d18b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"
c","subtype":"Figure","type":"Plot"},"ticker":{"id":"938b2fad-3cf4-4696-87a8-40351deeeb02","type":"BasicTicker"}},"id":"3d653431-726a-4f83-9abf-89e1149fe5d5","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"5929dc2c-244f-44f2-a042-6eee9bc36c2c","s ...

# %% [markdown]
# ## Bcolz carrays (in-memory)

# %%
c1 = bcolz.carray(a1, chunklen=chunks[0],
                  cparams=bcolz.cparams(cname='lz4', clevel=1, shuffle=2))
c1
# Out:
# carray((200000000,), uint16)
#   nbytes := 381.47 MB; cbytes := 318.98 MB; ratio: 1.20
#   cparams := cparams(clevel=1, shuffle=2, cname='lz4', quantize=0)
#   chunklen := 1048576; chunksize: 2097152; blocksize: 16384
# [1314 2727 2905 ..., 1958 1325 1971]

# %%
c2 = bcolz.zeros(a1.shape, chunklen=chunks[0], dtype=a1.dtype, 
                 cparams=bcolz.cparams(cname='lz4', clevel=1, shuffle=2))
c2
# Out:
# carray((200000000,), uint16)
#   nbytes := 381.47 MB; cbytes := 2.00 MB; ratio: 190.73
#   cparams := cparams(clevel=1, shuffle=2, cname='lz4', quantize=0)
#   chunklen := 1048576; chunksize: 2097152; blocksize: 4096
# [0 0 0 ..., 0 0 0]

# %%
profile_dask_copy(c1, c2, chunks, lock=True, dt=0.05)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6b775ffb-6b30-47f9-a2ce-02b5277899b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6b775ffb-6b30-47f9-a2ce-02b5277899b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6b775ffb-6b30-47f9-a2ce-02b5277899b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b5967fc4-33b4-4c8e-8657-6301fe59774e":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["function","key","x","color","width","y"],"data":{"color":["#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8"],"function":["store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), *, *)","store(getarray(...), * ...

# %%
# not sure it's safe to use bcolz without a lock, but what the heck...
profile_dask_copy(c1, c2, chunks, lock=False, dt=0.05)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="8028f003-0066-405a-9132-8f1341ddfa6b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8028f003-0066-405a-9132-8f1341ddfa6b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8028f003-0066-405a-9132-8f1341ddfa6b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1849bdc2-762f-4385-b1a3-c4e5547782db":{"roots":{"references":[{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"ba9dc322-0349-47a1-a2d2-373db155c1be","type":"HoverTool"},{"id":"4d3f5605-ced8-49bd-a9dd-6ea42eafd393","type":"SaveTool"},{"id":"7b42db7a-4b8e-4d21-bb1b-cda0d4b1c72e","type":"ResetTool"},{"id":"5bca8308-051a-4df7-8ee4-e36e0100e046","type":"ResizeTool"},{"id":"77ddd716-b74e-47cc-8d52-a7fbdc53aca1","type":"WheelZoomTool"},{"id":"60bcd8ea-119b-4d4f-a825-758ef1b32bbd","type":"PanTool"},{"id":"eded07e5-bdca-4dbc-bf90-ed6e6b9a73e1","type":"SaveTool"},{"id":"73903c35-8654-4d6f-8bcb-4c1c5a949cee","type":"ResetTool"},{"id":"d6979d39-67b3-4a32-a5bb-d2acd4108f93","type":"ResizeTool"},{"id":"959064ff-0f69-42ea-ba5a-68cec5862ed5","type":"WheelZoomTool"},{"id":"7026cfee-3e0d-44a6-aa6d-6f3ee2d96b3c","type":"PanTool"}]},"id":"866b7d7d-a247-4fdf-bc62-9b7687ad3ad9","type":"ToolbarBox"},{"attributes":{},"id":"b4d077a0-e623-42a2-9c41-5f55f40820de","type":"BasicTickFormatter"},{"attributes":{"axis_label":"% CPU","formatter":{"id":"70063a45-925a-42eb-9e9c-4bc1f411fe8e","type":"BasicTickFormatter"},"plot":{"id":"5fb4c231-4c4b-415e-88c7-d14a1d3c34b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d6b38772-699a-4d2b-87e3-0789696215ba","type":"BasicTicker"}},"id":"b8e3eefe-e2b0-40c2-9de6-a4c3a4a9e95f","type":"LinearAxis"},{"attributes":{"legends":[["% CPU",[{"id":"f01ebc13-c4b1-4bd5-a846-9cff86f49bb2","type":"GlyphRenderer"}]],["Memory",[{"id":"698ee91b-f9d8-41bd-a6c9-34fc8e55508a","type":"GlyphRenderer"}]]],"plot":{"id":"5fb4c231-4c4b-415e-88c7-d14a1d3c34b8","subtype":"Figure","type":"Plot"}},"id":"ed95d0ee-5f60-4eb6-a0a0-4f7cd54d988c","type":"Legend"},{"attributes":{"callback":null,"plot":{"id":"9ab32d95-5e8a-4a73-9aa1-2228f7ed1b83","subtype":"Figure","type":"Plot"},"point_policy":"follow_mouse","tooltips":"\n    <div>\n        <span style=\"font-size: 14px; font-weight: bold;\">Key:</span>&nbsp;\n        <span style=\"font-size: 10px; font-family: Monaco, monospace;\">@key</span>\n    </div>\n    <div>\n        <span style=\"font-size: 14px; font-weight: bold;\">Task:</span>&nbsp;\n        <span style=\"font-size: 10px; font-family: Monaco, monospace;\">@function</span>\n    </div>\n    "},"id":"ba9dc322-0349-47a1-a2d2-373db155c1be","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ba9dc322-0349-47a1-a2d2-373db155c1be","type":"HoverTool"},{"id":"4d3f5605-ced8-49bd-a9dd-6ea42eafd393","type":"SaveTool"},{"id":"7b42db7a-4b8e-4d21-bb1b-cda0d4b1c72e","type":"ResetTool"},{"id":"5bca8308-051a-4df7-8ee4-e36e0100e046","type":"ResizeTool"},{"id":"77ddd716-b74e-47cc-8d52-a7fbdc53aca1","type":"WheelZoomTool"},{"id":"60bcd8ea-119b-4d4f-a825-758ef1b32bbd","type":"PanTool"}]},"id":"c9546885-83f1-4597-bad5-44935ad57744","type":"Toolbar"},{"attributes":{},"id":"d6b38772-699a-4d2b-87e3-0789696215ba","type":"BasicTicker"},{"attributes":{},"id":"f9d35243-9bd2-47fa-9499-36ff17127651","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"16417c37-d71f-4d05-a75a-4644784a4956","type":"Rect"},{"attributes":{},"id":"a771395e-d14a-44e1-aef5-01bade258832","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"1588f1db-3693-42f3-8ef5-a6fdc9f0c987","type":"Line"},{"attributes":{"fill_color":{"field":"color"},"height":{"units":"data","value":1},"line_color":{"value":"gray"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e4d77003-ee1b-442d-bb75-a33680cf6312","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.05074199801310897,0.10139772598 ...

# %%
# for comparison
# %timeit -n3 -r5 c2[:] = c1
# Out:
# 3 loops, best of 5: 649 ms per loop

# %%
# for comparison
# %timeit -n3 -r5 c1.copy()
# Out:
# 3 loops, best of 5: 557 ms per loop
